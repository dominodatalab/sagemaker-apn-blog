# %% [markdown]
# ### First, we're going to load up the appropriate libraries

# %%
import os
import requests
import boto3
import json
import pandas as pd
from datetime import datetime
from time import sleep
import pprint

# %% [markdown]
# ### Next, we set up Domino API credentials.
#
# Since we are running this Python code inside of a Domino workspace, we can pull these credentials directly from the Environment Variables. If you run this code outside of Domino, you will need to manually populate these variables.

# %%
dominoAPIHost = os.environ["DOMINO_API_HOST"].strip()
dominoAPIKey = os.environ["DOMINO_USER_API_KEY"].strip()
dominoUserName = os.environ["DOMINO_PROJECT_OWNER"].strip()
dominoProjectName = os.environ["DOMINO_PROJECT_NAME"].strip()

# %% [markdown]
# ### Now we will set up some ECR variables.
#
# Keep in mind that "domino-sagemaker-exports" is an example ECR repository, but you will need to create your own ECR repository in your AWS account.

# %%
ecrRegion = os.environ["AWS_DEFAULT_REGION"].strip()
ecrRepository = "domino-sagemaker-exports"

# %% [markdown]
# ### With configuration out of the way, we can now paste in some boilerplate code to wrap around the Domino SageMaker export API

# %%
# Generate ECR login details for Domino's API
def generateECRPushDetails(repository, tag):
    from base64 import b64decode
    
    ecrAccount = boto3.client("sts", region_name=ecrRegion).get_caller_identity().get("Account")
    ecrToken = boto3.client("ecr", region_name=ecrRegion).get_authorization_token(registryIds=[ecrAccount])
    ecrRegistry = ecrToken["authorizationData"][0]["proxyEndpoint"].lstrip("https://").lstrip("http://")
    ecrAuth = b64decode(ecrToken["authorizationData"][0]["authorizationToken"]).decode("utf-8").split(":")
    
    pushData = {
        "registryUrl": ecrRegistry,
        "repository": repository,
        "tag": tag,
        "username": ecrAuth[0],
        "password": ecrAuth[1]
    }
    
    return pushData

# Domino API Request Base Method to simplify making Domino API calls
def dominoRequest(urlPath, requestType, json = None):
    url = "{DOMINO_HOST}{URL_PATH}".format(
        DOMINO_HOST = dominoAPIHost,
        URL_PATH = urlPath
    )
    
    session = requests.Session()
    session.headers.update({
        "X-Domino-Api-Key": dominoAPIKey,
        "Content-Type": "application/json",
        "Accept": "application/json"
    })
    response = None
    if requestType == "GET":
        response = session.get(url)
    elif requestType == "POST":
        response = session.post(url, json = json)
    
    response.raise_for_status()

    return response

# Domino API Wrapper for /v4/models/<MODEL_ID>/<MODEL_VERSION_ID>/exportImageForSagemaker
# This API request exports a Domino model to ECR as a SageMaker compatible format
def dominoSagemakerExport(modelID, modelVersion):
    modelVersionID = next(iter([modelVersionInfo.get("_id", None) for modelVersionInfo in dominoModelVersions(modelID) if modelVersionInfo.get("metadata", {}).get("number", None) == modelVersion]), None)
    exportStatus = None

    if modelVersionID:
        urlPath = "/v4/models/{MODEL_ID}/{MODEL_VERSION_ID}/exportImageForSagemaker".format(
            MODEL_ID = modelID,
            MODEL_VERSION_ID = modelVersionID
        )

        exportTag = "domino-{USERNAME}-{PROJECT_NAME}-{MODEL_ID}-{MODEL_VERSION}".format(
            USERNAME = dominoUserName,
            PROJECT_NAME = dominoProjectName,
            MODEL_ID = modelID,
            MODEL_VERSION = modelVersion
        )

        jsonData = generateECRPushDetails(ecrRepository, exportTag)

        exportStatus = json.loads(dominoRequest(urlPath, "POST", jsonData).text)
        exportStatus["tag"] = exportTag
        exportStatus["url"] = "https://{REGISTRY_URL}/{REPOSITORY}:{TAG}".format(
            REGISTRY_URL = jsonData["registryUrl"],
            REPOSITORY = jsonData["repository"],
            TAG = jsonData["tag"]
        )
    
    return exportStatus

## The following API calls are not required to publish a Domino model to ECR, but are going to be useful to list all of the running models for this Domino project

# Domino API Wrapper for /v1/projects/<USERNAME>/<PROJECT_NAME>/models
# This API Request returns all of the models associated with a particular Domino project
def dominoProjectModels():
    urlPath = "/v1/projects/{USERNAME}/{PROJECT_NAME}/models".format(
        USERNAME = dominoUserName,
        PROJECT_NAME = dominoProjectName
    )
    
    return json.loads(dominoRequest(urlPath, "GET").text).get("data", [])

# Domino API Wrapper for /v1/models/<MODEL_ID>/versions
# This API requests returns all of the Domino model versions for a particular model
def dominoModelVersions(modelID):
    urlPath = "/v1/models/{MODEL_ID}/versions".format(
        MODEL_ID = modelID
    )

    return json.loads(dominoRequest(urlPath, "GET").text).get("data", [])

# Domino API Wrapper for /v4/models/<EXPORT_ID>/getExportLogs
# This API requests get the logs for a Domino model export
def dominoModelExportLogs(exportID):
    urlPath = "/v4/models/{EXPORT_ID}/getExportLogs".format(
        EXPORT_ID = exportID
    )
    
    return json.loads(json.loads(dominoRequest(urlPath, "GET").text).get("logs", None))

# Domino API Wrapper for /v4/models/<EXPORT_ID>/getExportImageStatus
# This API request gets that status of a Domino model export
def dominoModelExportStatus(exportID):
    urlPath = "/v4/models/{EXPORT_ID}/getExportImageStatus".format(
        EXPORT_ID = exportID
    )
    
    return json.loads(dominoRequest(urlPath, "GET").text)

# %% [markdown]
# ### Now, we just need to select which model we want to export.
#
# We can visualize the models associated with our current Domino Project with the following code

# %%
dominoModels = []
for model in dominoProjectModels():
    for modelVersion in dominoModelVersions(model["id"]):
        dominoModel = {
            "Name": model["name"],
            "Model ID": model["id"],
            "Version": modelVersion["metadata"]["number"],
            "Published": datetime.fromtimestamp(float(modelVersion["metadata"]["created"]) / 1000),
            "File": modelVersion["file"],
            "Function": modelVersion["function"]
        }
        dominoModels.append(dominoModel)

models = pd.DataFrame.from_dict(dominoModels).sort_index()
models
# Out:
#                    File Function                  Model ID              Name  \
# 0  code/smallPredict.py  predict  5ed7dadecdfc18044c36d381  Churn Prediction
# 1       code/predict.py  predict  5ed7dadecdfc18044c36d381  Churn Prediction
#
#                 Published  Version
# 0 2020-06-11 17:33:19.346        2
# 1 2020-06-03 17:16:15.049        1

# %% [markdown]
# The Domino SageMaker Export API will require us to use the Model ID and Model Version. In this case, we will select model ID "5ed7dadecdfc18044c36d381" and model version 2.

# %% [markdown]
# ### Finally, we call our model export API with the above parameters and wait for it to finish.

# %%
modelExport = dominoSagemakerExport("5ed7dadecdfc18044c36d381", 2)

# How often, in seconds, to check the status of the model export
SLEEP_TIME_SECONDS = 10

while modelExport:
    status = dominoModelExportStatus(modelExport["exportId"]).get("status", None)
    if status:
        print(status)

        if status not in ["complete", "failed"]:
            sleep(SLEEP_TIME_SECONDS)
        else:
            break
# Out:
# preparing
# preparing
# preparing
# preparing
# preparing
# preparing
# preparing
# complete

# %% [markdown]
# ### Let's take a look at the export logs formore details

# %%
logs = dominoModelExportLogs(modelExport["exportId"])
pprint.pprint(logs)
# Out:
# {'lines': [{'content': 'Pulling and pushing Docker image '
#                        '100.97.86.247:5000/dom-mdl-5ed7dadecdfc18044c36d381-v2:2020611173319_t7msUfeb',
#             'timestamp': '20200826T214437.873Z'},
#            {'content': '', 'timestamp': '20200826T214437.873Z'},
#            {'content': 'Building Sagemaker Image...',
#             'timestamp': '20200826T214439.525Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214439.586Z'},
#            {'content': 'Starting', 'timestamp': '20200826T214439.586Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214439.586Z'},
#            {'content': 'Preparing project and dependencies',
#             'timestamp': '20200826T214439.860Z'},
#            {'content': 'Linking project to /mnt/imarchenko/CustomerChurn',
#             'timestamp': '20200826T214525.564Z'},
#            {'content': 'Project and dependencies linked',
#             'timestamp': '20200826T214525.565Z'},
#            {'content': 'Step 1/10 : FROM '
#                        '100.97.86.247:5000/domino-5ac7e95ae4b085124ffb64de:54',
#             'timestamp': '20200826T214528.266Z'},
#            {'content': '54: Pulling from domino-5ac7e95ae4b085124ffb64de',
#             'timestamp': '20200826T214528.816Z'},
#            {'content': 'ceae6610c462: Already exists',
#             'timestamp': '20200826T214528.817Z'},
#            {'content': 'f031a3c9b648: Already exists',
#             'timestamp': '20200826T214528.821Z'},
#            {'content': '37b6e6793125: Already exists',
#             'timestamp': '20200826T214528.825Z'},
#            {'content': '41c3e72d6bee: Already exists',
#             'timestamp': '20200826T214528.828Z'},
#            {'content': 'e0e883331037: Already exists',
#             'timestamp': '20200826T214528.832Z'},
#            {'content': '60d4955ac0a1: Already exists',
#             'timestamp': '20200826T214528.836Z'},
#            {'content': '6ed8afaf826b: Already exists',
#             'timestamp': '20200826T214528.840Z'},
#            {'content': '50f838061890: Already exists',
#             'timestamp': '20200826T214528.844Z'},
#            {'content': '936483f09479: Already exists',
#             'timestamp': '20200826T214528.847Z'},
#            {'content': 'dc4ec5bff5a8: Already exists',
#             'timestamp': '20200826T214528.851Z'},
#            {'content': '94c3b174c646: Already exists',
#             'timestamp': '20200826T214528.854Z'},
#            {'content': '356f3d588f40: Already exists',
#             'timestamp': '20200826T214528.858Z'},
#            {'content': '4f93bfdc8741: Already exists',
#             'timestamp': '20200826T214528.862Z'},
#            {'content': 'a03f171819eb: Already exists',
#             'timestamp': '20200826T214528.865Z'},
#            {'content': '49b67b872dfe: Already exists',
#             'timestamp': '20200826T214528.869Z'},
#            {'content': '0418ab1f94d0: Already exists',
#             'timestamp': '20200826T214528.873Z'},
#            {'content': 'fbf6354e47b7: Already exists',
#             'timestamp': '20200826T214528.876Z'},
#            {'content': 'a6987d7e9e60: Already exists',
#             'timestamp': '20200826T214528.880Z'},
#            {'content': '6d9b1599fadf: Already exists',
#             'timestamp': '20200826T214528.883Z'},
#            {'content': 'c88c9fb3ba38: Already exists',
#             'timestamp': '20200826T214528.887Z'},
#            {'content': '61ee36896c17: Already exists',
#             'timestamp': '20200826T214528.891Z'},
#            {'content': 'aa3facacaf98: Already exists',
#             'timestamp': '20200826T214528.895Z'},
#            {'content': 'dd9b1da7d1a6: Already exists',
#             'timestamp': '20200826T214528.900Z'},
#            {'content': '84caae71cab8: Already exists',
#             'timestamp': '20200826T214528.904Z'},
#            {'content': 'fe8ac08e493e: Already exists',
#             'timestamp': '20200826T214528.907Z'},
#            {'content': '1775bcfb9d17: Already exists',
#             'timestamp': '20200826T214528.911Z'},
#            {'content': '420ef766e6a3: Already exists',
#             'timestamp': '20200826T214528.915Z'},
#            {'content': '386497feb111: Already exists',
#             'timestamp': '20200826T214528.919Z'},
#            {'content': '9ad7ba88cae8: Already exists',
#             'timestamp': '20200826T214528.923Z'},
#            {'content': '971ea3b3fc12: Already exists',
#             'timestamp': '20200826T214528.927Z'},
#            {'content': '8924d409d4e3: Already exists',
#             'timestamp': '20200826T214528.931Z'},
#            {'content': 'b69af71a2e02: Already exists',
#             'timestamp': '20200826T214528.934Z'},
#            {'content': 'b2c719ca6f28: Already exists',
#             'timestamp': '20200826T214528.938Z'},
#            {'content': 'd718f945de51: Already exists',
#             'timestamp': '20200826T214528.942Z'},
#            {'content': '18735f1394cb: Already exists',
#             'timestamp': '20200826T214528.946Z'},
#            {'content': '4ed398a6bebd: Already exists',
#             'timestamp': '20200826T214528.950Z'},
#            {'content': 'e2f229d70127: Already exists',
#             'timestamp': '20200826T214528.954Z'},
#            {'content': '3034d3195414: Already exists',
#             'timestamp': '20200826T214528.957Z'},
#            {'content': 'bd3ef1ff5a65: Already exists',
#             'timestamp': '20200826T214528.962Z'},
#            {'content': '3cd657ea1c25: Already exists',
#             'timestamp': '20200826T214528.965Z'},
#            {'content': '36abfea81b6c: Already exists',
#             'timestamp': '20200826T214528.970Z'},
#            {'content': '8ee9b418825d: Pulling fs layer',
#             'timestamp': '20200826T214528.973Z'},
#            {'content': '3c002c6446e8: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': '51c247f0d4ec: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': 'f8337736d5b7: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': 'b581e7ebc220: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': 'aab844e52f36: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': '9173c88053ee: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': 'b2b6079262d3: Pulling fs layer',
#             'timestamp': '20200826T214528.974Z'},
#            {'content': 'ade0f86295b5: Pulling fs layer',
#             'timestamp': '20200826T214528.975Z'},
#            {'content': 'e823ee1b4ef7: Pulling fs layer',
#             'timestamp': '20200826T214528.975Z'},
#            {'content': '6fffbe32b814: Pulling fs layer',
#             'timestamp': '20200826T214528.975Z'},
#            {'content': '7071d39cd795: Pulling fs layer',
#             'timestamp': '20200826T214528.975Z'},
#            {'content': 'aab844e52f36: Waiting',
#             'timestamp': '20200826T214528.975Z'},
#            {'content': 'e823ee1b4ef7: Waiting',
#             'timestamp': '20200826T214528.975Z'},
#            {'content': '6fffbe32b814: Waiting',
#             'timestamp': '20200826T214528.976Z'},
#            {'content': '9173c88053ee: Waiting',
#             'timestamp': '20200826T214528.976Z'},
#            {'content': '7071d39cd795: Waiting',
#             'timestamp': '20200826T214528.976Z'},
#            {'content': 'ade0f86295b5: Waiting',
#             'timestamp': '20200826T214528.977Z'},
#            {'content': 'f8337736d5b7: Waiting',
#             'timestamp': '20200826T214528.977Z'},
#            {'content': 'b581e7ebc220: Waiting',
#             'timestamp': '20200826T214528.977Z'},
#            {'content': '8ee9b418825d: Downloading',
#             'timestamp': '20200826T214529.382Z'},
#            {'content': '8ee9b418825d: Verifying Checksum',
#             'timestamp': '20200826T214529.383Z'},
#            {'content': '8ee9b418825d: Download complete',
#             'timestamp': '20200826T214529.383Z'},
#            {'content': '8ee9b418825d: Extracting',
#             'timestamp': '20200826T214529.383Z'},
#            {'content': '51c247f0d4ec: Downloading',
#             'timestamp': '20200826T214529.425Z'},
#            {'content': '3c002c6446e8: Downloading',
#             'timestamp': '20200826T214529.447Z'},
#            {'content': '8ee9b418825d: Pull complete',
#             'timestamp': '20200826T214529.473Z'},
#            {'content': '51c247f0d4ec: Download complete',
#             'timestamp': '20200826T214529.476Z'},
#            {'content': '3c002c6446e8: Download complete',
#             'timestamp': '20200826T214529.497Z'},
#            {'content': '3c002c6446e8: Extracting',
#             'timestamp': '20200826T214529.498Z'},
#            {'content': '3c002c6446e8: Pull complete',
#             'timestamp': '20200826T214529.653Z'},
#            {'content': '51c247f0d4ec: Extracting',
#             'timestamp': '20200826T214529.658Z'},
#            {'content': 'f8337736d5b7: Downloading',
#             'timestamp': '20200826T214529.801Z'},
#            {'content': 'f8337736d5b7: Verifying Checksum',
#             'timestamp': '20200826T214529.816Z'},
#            {'content': 'f8337736d5b7: Download complete',
#             'timestamp': '20200826T214529.816Z'},
#            {'content': '51c247f0d4ec: Pull complete',
#             'timestamp': '20200826T214529.868Z'},
#            {'content': 'f8337736d5b7: Extracting',
#             'timestamp': '20200826T214529.871Z'},
#            {'content': 'b581e7ebc220: Downloading',
#             'timestamp': '20200826T214529.928Z'},
#            {'content': 'aab844e52f36: Downloading',
#             'timestamp': '20200826T214529.933Z'},
#            {'content': 'aab844e52f36: Verifying Checksum',
#             'timestamp': '20200826T214529.934Z'},
#            {'content': 'aab844e52f36: Download complete',
#             'timestamp': '20200826T214529.934Z'},
#            {'content': 'f8337736d5b7: Pull complete',
#             'timestamp': '20200826T214530.003Z'},
#            {'content': '9173c88053ee: Downloading',
#             'timestamp': '20200826T214530.240Z'},
#            {'content': '9173c88053ee: Verifying Checksum',
#             'timestamp': '20200826T214530.327Z'},
#            {'content': '9173c88053ee: Download complete',
#             'timestamp': '20200826T214530.327Z'},
#            {'content': 'b2b6079262d3: Downloading',
#             'timestamp': '20200826T214530.347Z'},
#            {'content': 'b581e7ebc220: Download complete',
#             'timestamp': '20200826T214530.378Z'},
#            {'content': 'b581e7ebc220: Extracting',
#             'timestamp': '20200826T214530.380Z'},
#            {'content': 'b2b6079262d3: Download complete',
#             'timestamp': '20200826T214530.394Z'},
#            {'content': 'ade0f86295b5: Downloading',
#             'timestamp': '20200826T214530.759Z'},
#            {'content': 'b581e7ebc220: Pull complete',
#             'timestamp': '20200826T214530.767Z'},
#            {'content': 'aab844e52f36: Extracting',
#             'timestamp': '20200826T214530.770Z'},
#            {'content': 'e823ee1b4ef7: Downloading',
#             'timestamp': '20200826T214530.796Z'},
#            {'content': 'aab844e52f36: Pull complete',
#             'timestamp': '20200826T214530.852Z'},
#            {'content': '9173c88053ee: Extracting',
#             'timestamp': '20200826T214530.856Z'},
#            {'content': '6fffbe32b814: Downloading',
#             'timestamp': '20200826T214530.874Z'},
#            {'content': 'e823ee1b4ef7: Verifying Checksum',
#             'timestamp': '20200826T214530.953Z'},
#            {'content': 'e823ee1b4ef7: Download complete',
#             'timestamp': '20200826T214530.953Z'},
#            {'content': '6fffbe32b814: Verifying Checksum',
#             'timestamp': '20200826T214530.975Z'},
#            {'content': '6fffbe32b814: Download complete',
#             'timestamp': '20200826T214530.975Z'},
#            {'content': '9173c88053ee: Pull complete',
#             'timestamp': '20200826T214531.010Z'},
#            {'content': 'b2b6079262d3: Extracting',
#             'timestamp': '20200826T214531.014Z'},
#            {'content': 'ade0f86295b5: Verifying Checksum',
#             'timestamp': '20200826T214531.126Z'},
#            {'content': 'ade0f86295b5: Download complete',
#             'timestamp': '20200826T214531.126Z'},
#            {'content': 'b2b6079262d3: Pull complete',
#             'timestamp': '20200826T214531.220Z'},
#            {'content': 'ade0f86295b5: Extracting',
#             'timestamp': '20200826T214531.224Z'},
#            {'content': '7071d39cd795: Downloading',
#             'timestamp': '20200826T214531.354Z'},
#            {'content': '7071d39cd795: Verifying Checksum',
#             'timestamp': '20200826T214531.354Z'},
#            {'content': '7071d39cd795: Download complete',
#             'timestamp': '20200826T214531.354Z'},
#            {'content': 'ade0f86295b5: Pull complete',
#             'timestamp': '20200826T214531.393Z'},
#            {'content': 'e823ee1b4ef7: Extracting',
#             'timestamp': '20200826T214531.397Z'},
#            {'content': 'e823ee1b4ef7: Pull complete',
#             'timestamp': '20200826T214531.569Z'},
#            {'content': '6fffbe32b814: Extracting',
#             'timestamp': '20200826T214531.575Z'},
#            {'content': '6fffbe32b814: Pull complete',
#             'timestamp': '20200826T214531.746Z'},
#            {'content': '7071d39cd795: Extracting',
#             'timestamp': '20200826T214531.750Z'},
#            {'content': '7071d39cd795: Pull complete',
#             'timestamp': '20200826T214531.848Z'},
#            {'content': 'Digest: '
#                        'sha256:951b0c5312ba224ff0266a38b6ed0ba1ffc324aaa1a908e350b5a8436eb34241',
#             'timestamp': '20200826T214531.855Z'},
#            {'content': 'Status: Downloaded newer image for '
#                        '100.97.86.247:5000/domino-5ac7e95ae4b085124ffb64de:54',
#             'timestamp': '20200826T214531.859Z'},
#            {'content': ' ---> 6215083b172d',
#             'timestamp': '20200826T214531.860Z'},
#            {'content': 'Step 2/10 : ADD files /',
#             'timestamp': '20200826T214531.860Z'},
#            {'content': ' ---> d7bf09d667ad',
#             'timestamp': '20200826T214532.214Z'},
#            {'content': 'Step 3/10 : WORKDIR /mnt/imarchenko/CustomerChurn',
#             'timestamp': '20200826T214532.215Z'},
#            {'content': ' ---> Running in f29bb25a0d7a',
#             'timestamp': '20200826T214532.260Z'},
#            {'content': 'Removing intermediate container f29bb25a0d7a',
#             'timestamp': '20200826T214532.418Z'},
#            {'content': ' ---> 6c428d41e23e',
#             'timestamp': '20200826T214532.418Z'},
#            {'content': 'Step 4/10 : ENV '
#                        'DOMINO_WORKING_DIR=/mnt/imarchenko/CustomerChurn',
#             'timestamp': '20200826T214532.418Z'},
#            {'content': ' ---> Running in 24d4ffd1a505',
#             'timestamp': '20200826T214532.464Z'},
#            {'content': 'Removing intermediate container 24d4ffd1a505',
#             'timestamp': '20200826T214532.570Z'},
#            {'content': ' ---> fe52de053afe',
#             'timestamp': '20200826T214532.570Z'},
#            {'content': 'Step 5/10 : ENV '
#                        'DOMINO_USER_HOST=http://frontend-nucleus.domino-vip2-platform:80',
#             'timestamp': '20200826T214532.570Z'},
#            {'content': ' ---> Running in bd3c911714e3',
#             'timestamp': '20200826T214532.616Z'},
#            {'content': 'Removing intermediate container bd3c911714e3',
#             'timestamp': '20200826T214532.718Z'},
#            {'content': ' ---> 31198897e053',
#             'timestamp': '20200826T214532.718Z'},
#            {'content': 'Step 6/10 : ENV DOMINO_PROJECT_OWNER=imarchenko',
#             'timestamp': '20200826T214532.718Z'},
#            {'content': ' ---> Running in 0111a917dfa0',
#             'timestamp': '20200826T214532.768Z'},
#            {'content': 'Removing intermediate container 0111a917dfa0',
#             'timestamp': '20200826T214532.879Z'},
#            {'content': ' ---> 6a092175ed9e',
#             'timestamp': '20200826T214532.879Z'},
#            {'content': 'Step 7/10 : ENV DOMINO_PROJECT_NAME=CustomerChurn',
#             'timestamp': '20200826T214532.879Z'},
#            {'content': ' ---> Running in 610a74501884',
#             'timestamp': '20200826T214532.920Z'},
#            {'content': 'Removing intermediate container 610a74501884',
#             'timestamp': '20200826T214533.034Z'},
#            {'content': ' ---> 0a6f4bdbaee9',
#             'timestamp': '20200826T214533.034Z'},
#            {'content': 'Step 8/10 : RUN /domino/model-manager/validate-env',
#             'timestamp': '20200826T214533.034Z'},
#            {'content': ' ---> Running in a0e8b9767e56',
#             'timestamp': '20200826T214533.076Z'},
#            {'content': 'Collecting requests==2.19.0',
#             'timestamp': '20200826T214534.250Z'},
#            {'content': '  Downloading requests-2.19.0-py2.py3-none-any.whl (91 '
#                        'kB)',
#             'timestamp': '20200826T214534.299Z'},
#            {'content': 'Collecting urllib3<1.24,>=1.21.1',
#             'timestamp': '20200826T214534.392Z'},
#            {'content': '  Downloading urllib3-1.23-py2.py3-none-any.whl (133 '
#                        'kB)',
#             'timestamp': '20200826T214534.403Z'},
#            {'content': 'Requirement already satisfied: certifi>=2017.4.17 in '
#                        '/usr/local/anaconda/lib/python3.6/site-packages (from '
#                        'requests==2.19.0) (2019.3.9)',
#             'timestamp': '20200826T214534.442Z'},
#            {'content': 'Requirement already satisfied: chardet<3.1.0,>=3.0.2 '
#                        'in /usr/local/anaconda/lib/python3.6/site-packages '
#                        '(from requests==2.19.0) (3.0.4)',
#             'timestamp': '20200826T214534.443Z'},
#            {'content': 'Collecting idna<2.8,>=2.5',
#             'timestamp': '20200826T214534.470Z'},
#            {'content': '  Downloading idna-2.7-py2.py3-none-any.whl (58 kB)',
#             'timestamp': '20200826T214534.480Z'},
#            {'content': 'Installing collected packages: urllib3, idna, requests',
#             'timestamp': '20200826T214535.260Z'},
#            {'content': '  Attempting uninstall: urllib3',
#             'timestamp': '20200826T214535.260Z'},
#            {'content': '    Found existing installation: urllib3 1.24.2',
#             'timestamp': '20200826T214535.260Z'},
#            {'content': '    Uninstalling urllib3-1.24.2:',
#             'timestamp': '20200826T214535.272Z'},
#            {'content': '      Successfully uninstalled urllib3-1.24.2',
#             'timestamp': '20200826T214535.287Z'},
#            {'content': '  Attempting uninstall: idna',
#             'timestamp': '20200826T214535.352Z'},
#            {'content': '    Found existing installation: idna 2.8',
#             'timestamp': '20200826T214535.352Z'},
#            {'content': '    Uninstalling idna-2.8:',
#             'timestamp': '20200826T214535.355Z'},
#            {'content': '      Successfully uninstalled idna-2.8',
#             'timestamp': '20200826T214535.908Z'},
#            {'content': '  Attempting uninstall: requests',
#             'timestamp': '20200826T214535.976Z'},
#            {'content': '    Found existing installation: requests 2.21.0',
#             'timestamp': '20200826T214535.977Z'},
#            {'content': '    Uninstalling requests-2.21.0:',
#             'timestamp': '20200826T214535.983Z'},
#            {'content': '      Successfully uninstalled requests-2.21.0',
#             'timestamp': '20200826T214535.989Z'},
#            {'content': 'Successfully installed idna-2.7 requests-2.19.0 '
#                        'urllib3-1.23',
#             'timestamp': '20200826T214536.108Z'},
#            {'content': '\x1bWARNING: You are using pip version 20.0.2; '
#                        'however, version 20.2.2 is available.',
#             'timestamp': '20200826T214536.319Z'},
#            {'content': 'You should consider upgrading via the '
#                        "'/usr/local/anaconda/bin/python -m pip install "
#                        "--upgrade pip' command.",
#             'timestamp': '20200826T214536.319Z'},
#            {'content': '\x1b', 'timestamp': '20200826T214536.319Z'},
#            {'content': 'wget is /usr/bin/wget',
#             'timestamp': '20200826T214536.377Z'},
#            {'content': 'Flask==1.0.2', 'timestamp': '20200826T214536.823Z'},
#            {'content': 'Flask-Compress==1.4.0',
#             'timestamp': '20200826T214536.823Z'},
#            {'content': 'Flask-Cors==3.0.7',
#             'timestamp': '20200826T214536.823Z'},
#            {'content': 'jsonify==0.5', 'timestamp': '20200826T214537.255Z'},
#            {'content': 'uWSGI==2.0.18', 'timestamp': '20200826T214537.690Z'},
#            {'content': 'requests==2.19.0', 'timestamp': '20200826T214538.125Z'},
#            {'content': 'Removing intermediate container a0e8b9767e56',
#             'timestamp': '20200826T214538.534Z'},
#            {'content': ' ---> 59d6205e58b6',
#             'timestamp': '20200826T214538.534Z'},
#            {'content': 'Step 9/10 : ENTRYPOINT [ '
#                        '"/domino/model-manager/launch" ]',
#             'timestamp': '20200826T214538.534Z'},
#            {'content': ' ---> Running in 1a33a08d57a7',
#             'timestamp': '20200826T214538.584Z'},
#            {'content': 'Removing intermediate container 1a33a08d57a7',
#             'timestamp': '20200826T214538.686Z'},
#            {'content': ' ---> 0f7e73f1300c',
#             'timestamp': '20200826T214538.686Z'},
#            {'content': 'Step 10/10 : CMD ["serve"]',
#             'timestamp': '20200826T214538.686Z'},
#            {'content': ' ---> Running in c2d57fd2eb21',
#             'timestamp': '20200826T214538.732Z'},
#            {'content': 'Removing intermediate container c2d57fd2eb21',
#             'timestamp': '20200826T214538.854Z'},
#            {'content': ' ---> 33a67d070964',
#             'timestamp': '20200826T214538.854Z'},
#            {'content': 'Successfully built 33a67d070964',
#             'timestamp': '20200826T214538.864Z'},
#            {'content': 'Successfully tagged '
#                        '100.97.86.247:5000/dom-mdl-5ed7dadecdfc18044c36d381-v2:2020611173319_t7msUfeb',
#             'timestamp': '20200826T214538.871Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214538.956Z'},
#            {'content': 'Tagging', 'timestamp': '20200826T214538.956Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214538.956Z'},
#            {'content': 'Pushing image '
#                        '573040241134.dkr.ecr.us-east-1.amazonaws.com/domino-sagemaker-exports:domino-imarchenko-CustomerChurn-5ed7dadecdfc18044c36d381-2',
#             'timestamp': '20200826T214539.002Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214539.002Z'},
#            {'content': 'Pushing', 'timestamp': '20200826T214539.002Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214539.002Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214546.281Z'},
#            {'content': 'Succeeded', 'timestamp': '20200826T214546.281Z'},
#            {'content': '======================================================================',
#             'timestamp': '20200826T214546.281Z'},
#            {'content': 'SUCCESS: Successfully pulled and pushed image '
#                        '100.97.86.247:5000/dom-mdl-5ed7dadecdfc18044c36d381-v2:2020611173319_t7msUfeb',
#             'timestamp': '20200826T214546.359Z'}]}
